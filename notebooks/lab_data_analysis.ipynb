# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Set Pandas display options to show all columns and rows while printing
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
# import data
df = pd.read_csv('../data/IEEE_2024_positioning_evaluation_with_size_data.csv')

# %%
# delta between predicted and reference
df['Dx'] = df['Xestimated[m]'] - df['Xgt[m]']
df['Dy'] = df['Yestimated[m]'] - df['Ygt[m]']
df['Dz'] = df['Zestimated[m]'] - df['Zgt[m]']

# %%
df.head(5)
# Out:
#              image setup  Trunk-Cam_dist[mm] ObjType  Position  ObjSizeX  \
# 0  color_1_1_0.png    2D              1549.0   Apple         1   0.06909
# 1  color_1_1_0.png    2D              1549.0   Apple         2   0.06463
# 2  color_1_1_0.png    2D              1549.0   Apple         3   0.06987
# 3  color_1_1_0.png    2D              1549.0   Apple         4   0.06508
# 4  color_1_1_0.png    2D              1549.0   Apple         5   0.06464
#
#    ObjSizeY  ObjSizeZ  Xgt[m]  Ygt[m]  Zgt[m]  Xestimated[m]  Yestimated[m]  \
# 0   0.06714   0.05979   0.465   0.072   1.860          0.465          0.060
# 1   0.06205   0.05376   0.000   0.072   1.863          0.000          0.060
# 2   0.06844   0.06317  -0.465   0.073   1.858         -0.465          0.036
# 3   0.06317   0.05831   0.467   0.072   1.561          0.467          0.050
# 4   0.06348   0.06145   0.000   0.073   1.559          0.000          0.060
#
#    Zestimated[m]  Manhattan[m]  Euclidean[m]   Dx     Dy    Dz
# 0          1.910          0.06      0.050990  0.0 -0.012  0.05
# 1          1.913          0.06      0.050990  0.0 -0.012  0.05
# 2          1.878          0.05      0.036056  0.0 -0.037  0.02
# 3          1.601          0.06      0.044721  0.0 -0.022  0.04
# 4          1.609          0.06      0.050990  0.0 -0.013  0.05

# %%
# chunks
# 2D
df_2D = df.loc[df['setup'] == '2D'].copy()
df_2D_apples = df.loc[(df['setup'] == '2D') & (df['ObjType'] == 'Apple')].copy()
df_2D_tennisballs = df.loc[(df['setup'] == '2D') & (df['ObjType'] == 'Tennis_ball')].copy()

# 3d
df_3D = df.loc[df['setup'] == '3D'].copy()
df_3D_apples = df.loc[(df['setup'] == '3D') & (df['ObjType'] == 'Apple')].copy()
df_3D_tennisballs = df.loc[(df['setup'] == '3D') & (df['ObjType'] == 'Tennis_ball')].copy()

# %%
df_2D_apples.describe()
# Out:
#        Trunk-Cam_dist[mm]    Position    ObjSizeX    ObjSizeY    ObjSizeZ  \
# count          396.000000  396.000000  396.000000  396.000000  396.000000
# mean          1532.545455    8.000000    0.058414    0.056860    0.052183
# std              9.853892    4.288932    0.006432    0.006006    0.005149
# min           1511.000000    1.000000    0.046500    0.046400    0.040080
# 25%           1528.000000    4.000000    0.053645    0.053490    0.048987
# 50%           1535.000000    8.000000    0.059625    0.057200    0.052430
# 75%           1538.000000   12.000000    0.064120    0.061150    0.055560
# max           1549.000000   15.000000    0.069870    0.068440    0.063170
#
#            Xgt[m]      Ygt[m]      Zgt[m]  Xestimated[m]  Yestimated[m]  \
# count  396.000000  396.000000  396.000000     396.000000     396.000000
# mean    -0.000098    0.055848    1.266076      -0.000098       0.038793
# std      0.384759    0.009869    0.422994       0.384759       0.012360
# min     -0.476000    0.033000    0.660000      -0.476000       0.000000
# 25%     -0.468250    0.051000    0.962000      -0.468250       0.030000
# 50%      0.000000    0.057000    1.264500       0.000000       0.040000
# 75%      0.468000    0.062000    1.564000       0.468000       0.050000
# max      0.476000    0.073000    1.880000       0.476000       0.062000
#
#        Zestimated[m]  Manhattan[m]  Euclidean[m]     Dx          Dy  \
# count     396.000000    396.000000    396.000000  396.0  396.000000
# mean        1.298374      0.051086      0.040287    0.0   -0.017056
# std         0.431450      0.018421      0.013405    0.0    0.014464
# min         0.652000      0.010000      0.010000    0.0   -0.059000
# 25%         0.982000      0.040000      0.030000    0.0   -0.027250
# 50%         1.305000      0.050000      0.040000    0.0   -0.017000
# 75%         1.613000      0.060000      0.050000    0.0   -0.007000
# max         1.949000      0.100000      0.072801    0.0    0.019000
#
#                Dz
# count  396.000000
# mean     0.032298
# std      0.013890
# min     -0.010000
# 25%      0.020000
# 50%      0.030000
# 75%      0.040000
# max      0.070000

# %%
df_3D_apples.describe()
# Out:
#        Trunk-Cam_dist[mm]    Position    ObjSizeX    ObjSizeY    ObjSizeZ  \
# count          241.000000  241.000000  241.000000  240.000000  240.000000
# mean          1530.298755   13.024896    0.059908    0.057868    0.053047
# std              9.895809    7.116838    0.006249    0.005862    0.005041
# min           1517.000000    2.000000    0.047470    0.047050    0.041800
# 25%           1524.000000    7.000000    0.057870    0.055278    0.050533
# 50%           1531.000000   13.000000    0.061050    0.057455    0.052450
# 75%           1538.000000   19.000000    0.064860    0.061655    0.056388
# max           1552.000000   25.000000    0.069870    0.068440    0.063170
#
#            Xgt[m]      Ygt[m]     Zgt[m]  Xestimated[m]  Yestimated[m]  \
# count  240.000000  240.000000  240.00000     241.000000     240.000000
# mean    -0.002100    0.148900    1.24650      -0.002203       0.127921
# std      0.322418    0.116155    0.42615       0.321286       0.126007
# min     -0.473000    0.045000    0.62000      -0.473000       0.020000
# 25%     -0.265500    0.071000    0.93500      -0.272000       0.040000
# 50%      0.000000    0.092500    1.23650       0.000000       0.060000
# 75%      0.207500    0.206000    1.55350       0.170000       0.196500
# max      0.475000    0.499000    1.87900       0.475000       0.482000
#
#        Zestimated[m]  Manhattan[m]  Euclidean[m]          Dx          Dy  \
# count     240.000000    240.000000    240.000000  240.000000  240.000000
# mean        1.302792      0.086208      0.065074    0.001000   -0.020979
# std         0.429200      0.025239      0.016667    0.012232    0.023161
# min         0.670000      0.020000      0.020000   -0.020000   -0.071000
# 25%         0.982500      0.070000      0.053136    0.000000   -0.037000
# 50%         1.301000      0.090000      0.067082    0.000000   -0.024000
# 75%         1.621750      0.110000      0.077134    0.000000   -0.006000
# max         1.939000      0.140000      0.104403    0.050000    0.060000
#
#                Dz
# count  240.000000
# mean     0.056292
# std      0.016643
# min      0.020000
# 25%      0.050000
# 50%      0.060000
# 75%      0.060000
# max      0.100000

# %% [markdown]
# ## positioning error related to dimensionality (2D, 3D)

# %%
# Define the list of dataframes
dataframes = {
    '2D': df_2D,
    '2D_TB': df_2D_tennisballs,
    '3D_TB': df_3D_tennisballs,

    '3D': df_3D,
    '2D_apples': df_2D_apples,
    '3D_apples': df_3D_apples,
}

results = []

# Iterate through the dataframes and calculate RMSE values
for name, df_chunk in dataframes.items():
    
    rmse_manhattan = np.sqrt(np.sum(df_chunk['Manhattan[m]'] ** 2) / df_chunk['Manhattan[m]'].count())
    rmse_euclidean = np.sqrt(np.sum(df_chunk['Euclidean[m]'] ** 2) / df_chunk['Euclidean[m]'].count())

    results.append([name, rmse_manhattan, rmse_euclidean])

# Create a DataFrame from the results
rmse_df = pd.DataFrame(results, columns=['DataFrame', 'RMSE_Manhattan', 'RMSE_Euclidean'])

print(np.round(rmse_df, 3))
# Out:
#    DataFrame  RMSE_Manhattan  RMSE_Euclidean
# 0         2D           0.054           0.043
# 1      2D_TB           0.061           0.051
# 2      3D_TB           0.044           0.039
# 3         3D           0.083           0.063
# 4  2D_apples           0.054           0.042
# 5  3D_apples           0.090           0.067

# %%
# Add a new column to differentiate between 2D and 3D
rmse_df['Dimension'] = rmse_df['DataFrame'].apply(lambda x: '2D' if '2D' in x else '3D')
rmse_df['Object'] = rmse_df['DataFrame'].apply(lambda x: 'apple' if 'apples' in x else 'TB')

grouped_df = rmse_df.iloc[:, 1:-1].groupby('Dimension').mean()
grouped_df
# Out:
#            RMSE_Manhattan  RMSE_Euclidean
# Dimension
# 2D               0.056743        0.045368
# 3D               0.072104        0.056136

# %% [markdown]
# ## positioning error related to object type (Apple, Tennis ball)

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 6), sharey=True)

axes[0].grid(lw=.5)
axes[1].grid(lw=.5)


# Histogram for RMSE_Manhattan
for dimension, color in zip(['2D', '3D'], ['k', 'gray']):
    subset = rmse_df[rmse_df['Dimension'] == dimension]
    axes[0].bar(subset['DataFrame'], subset['RMSE_Manhattan'], color=color, label=dimension, alpha=0.7)

# Histogram for RMSE_Euclidean
for dimension, color in zip(['2D', '3D'], ['k', 'gray']):
    subset = rmse_df[rmse_df['Dimension'] == dimension]
    axes[1].bar(subset['DataFrame'], subset['RMSE_Euclidean'], color=color, label=dimension, alpha=0.7)


axes[0].set_title('RMSE Manhattan')
axes[0].set_xlabel('Trial')
axes[0].set_ylabel('RMSE [m]')
axes[0].legend()

axes[1].set_title('RMSE Euclidean')
axes[1].set_xlabel('Trial')
axes[1].legend()


plt.tight_layout()

plt.savefig('../docs/images/results.png', dpi=400)
plt.show()

# %%
mean_errors = rmse_df.groupby('Object')[['RMSE_Manhattan', 'RMSE_Euclidean']].mean().reset_index()
mean_errors
# Out:
#   Object  RMSE_Manhattan  RMSE_Euclidean
# 0     TB        0.060608        0.048724
# 1  apple        0.072055        0.054810

# %%
grouped_df = rmse_df.iloc[:, 1:].groupby(['Object', 'Dimension']).mean()
grouped_df
# Out:
#                   RMSE_Manhattan  RMSE_Euclidean
# Object Dimension
# TB     2D               0.057965        0.046826
#        3D               0.063250        0.050621
# apple  2D               0.054298        0.042453
#        3D               0.089812        0.067166

# %% [markdown]
# ## positioning error related to single positions

# %%
plt.figure(figsize=(15, 7))

plt.grid(lw = .5)



pos_1_15 = []
pos_16_25 = []

for pos in df['Position'].unique():

    df_pos = df.loc[df['Position'] == pos].copy()
    avg_error_x = np.sum(df_pos['Dx']) / len(df_pos)
    avg_error_y = np.sum(df_pos['Dy']) / len(df_pos)
    avg_error_z = np.sum(df_pos['Dz']) / len(df_pos)

    sum_error = np.abs(avg_error_x) + np.abs(avg_error_y) + np.abs(avg_error_z)  # this error is a manhattan error

    if pos <= 15:
        pos_1_15.append(sum_error)
        plt.bar(pos - 1, sum_error, color='gray', alpha=.9)
    else:
        pos_16_25.append(sum_error)
        plt.bar(pos - 1, sum_error, color='k', alpha=1)

plt.xlabel('$position-id$')
plt.ylabel('Error [m]')
plt.suptitle('Error per position')

# Set ticks to each group
plt.xticks(ticks=np.arange(len(df['Position'].unique())), labels=df['Position'].unique())

plt.tight_layout()

plt.savefig('../docs/images/positioning_errors-related_to_position.png', dpi=400)

plt.show()


print(f'[1 - 15] mean : {np.mean(pos_1_15) : .4f}')
print(f'[16 - 25] mean : {np.mean(pos_16_25) : .4f}')
# Out:
# [1 - 15] mean :  0.0550
# [16 - 25] mean :  0.0854

# %% [markdown]
# ## positioning error related to single axes

# %%
df.head(5)
# Out:
#              image setup  Trunk-Cam_dist[mm] ObjType  Position  ObjSizeX  \
# 0  color_1_1_0.png    2D              1549.0   Apple         1   0.06909
# 1  color_1_1_0.png    2D              1549.0   Apple         2   0.06463
# 2  color_1_1_0.png    2D              1549.0   Apple         3   0.06987
# 3  color_1_1_0.png    2D              1549.0   Apple         4   0.06508
# 4  color_1_1_0.png    2D              1549.0   Apple         5   0.06464
#
#    ObjSizeY  ObjSizeZ  Xgt[m]  Ygt[m]  Zgt[m]  Xestimated[m]  Yestimated[m]  \
# 0   0.06714   0.05979   0.465   0.072   1.860          0.465          0.060
# 1   0.06205   0.05376   0.000   0.072   1.863          0.000          0.060
# 2   0.06844   0.06317  -0.465   0.073   1.858         -0.465          0.036
# 3   0.06317   0.05831   0.467   0.072   1.561          0.467          0.050
# 4   0.06348   0.06145   0.000   0.073   1.559          0.000          0.060
#
#    Zestimated[m]  Manhattan[m]  Euclidean[m]   Dx     Dy    Dz
# 0          1.910          0.06      0.050990  0.0 -0.012  0.05
# 1          1.913          0.06      0.050990  0.0 -0.012  0.05
# 2          1.878          0.05      0.036056  0.0 -0.037  0.02
# 3          1.601          0.06      0.044721  0.0 -0.022  0.04
# 4          1.609          0.06      0.050990  0.0 -0.013  0.05

# %%
fig, ax = plt.subplots(1, 2, figsize=(15, 7), sharey=True)
ax[0].grid(lw=.5)
ax[1].grid(lw=.5)


for pos in df['Position'].unique():

    df_pos = df.loc[df['Position'] == pos].copy()
    avg_error_x = np.sum(df_pos['Dx']) / len(df_pos)
    avg_error_y = np.sum(df_pos['Dy']) / len(df_pos)
    avg_error_z = np.sum(df_pos['Dz']) / len(df_pos)
    sum_error = np.abs(avg_error_x) + np.abs(avg_error_y) + np.abs(avg_error_z)

    ax[0].bar(pos - 1.2, avg_error_x, width=0.15, color='r')
    ax[0].bar(pos - 1, avg_error_y, width=0.15, color='g')
    ax[0].bar(pos - 0.8, avg_error_z, width=0.15, color='b')
    ax[1].bar(pos - 1, sum_error, width=0.2, color='k', alpha=.7)

ax[0].bar(pos - 1.2, avg_error_x, width=0.15, color='r', label='X-axis')
ax[0].bar(pos - 1, avg_error_y, width=0.15, color='g', label='Y-axis')
ax[0].bar(pos - 0.8, avg_error_z, width=0.15, color='b', label='Z-axis')
ax[1].bar(pos - 1, sum_error, width=0.2, color='k', alpha=.6, label='Absolute Sum')


ax[0].set_xlabel('$position-id$')
ax[1].set_xlabel('$position-id$')
ax[0].set_ylabel('Error [m]')
plt.suptitle('Error per axis')

# Set ticks to each group
ax[0].set_xticks(ticks=np.arange(len(df['Position'].unique())), labels=df['Position'].unique())
ax[1].set_xticks(ticks=np.arange(len(df['Position'].unique())), labels=df['Position'].unique())

ax[0].legend(loc='upper left')
ax[1].legend(loc='upper left')
plt.tight_layout()

plt.savefig('../docs/images/error_per_axis.png', dpi=400)

plt.show()

# %%
plt.figure(figsize=(5, 5))

pos_list = []
sum_e_list = []

for pos in df['Position'].unique():

    df_pos = df.loc[df['Position'] == pos].copy()
    avg_error_x = np.sum(df_pos['Dx']) / len(df_pos)
    avg_error_y = np.sum(df_pos['Dy']) / len(df_pos)
    avg_error_z = np.sum(df_pos['Dz']) / len(df_pos)
    sum_error = np.abs(avg_error_x) + np.abs(avg_error_y) + np.abs(avg_error_z)
    pos_list.append(pos-1)
    sum_e_list.append(sum_error)


plt.plot(pos_list, sum_e_list, 'o')

print(f'Pos [1-15]:\n{np.corrcoef(pos_list[:16], sum_e_list[:16])}\n')
print(f'Pos [16-25]:\n{np.corrcoef(pos_list[16:], sum_e_list[16:])}')

plt.xlabel('$position-id$')
plt.ylabel('Error [m]')
plt.suptitle('Error relation with object vertical position')

plt.tight_layout()
plt.grid()
plt.savefig('../docs/images/error_relation_with_vertical_position.png', dpi=400)

plt.show()
# Out:
# Pos [1-15]:
# [[1.         0.19623095]
#  [0.19623095 1.        ]]
#
# Pos [16-25]:
# [[ 1.         -0.38309122]
#  [-0.38309122  1.        ]]

# %% [markdown]
# mean error per each axis (not focused on position)

# %%
x = []
y = []
z = []
avg = []

# compute MBE (Mean Bias Error)
for pos in df['Position'].unique():

    df_pos = df.loc[df['Position'] == pos].copy()
    x.append((np.sum(df_pos['Dx']) / len(df_pos)))
    y.append((np.sum(df_pos['Dy']) / len(df_pos)))
    z.append((np.sum(df_pos['Dz']) / len(df_pos)))

print(f'X: {np.mean(x) : .4f}')
print(f'Y: {np.mean(y) : .4f}')
print(f'Z: {np.mean(z) : .4f}')
# Out:
# X:  0.0008
# Y: -0.0103
# Z:  0.0427

# %% [markdown]
# ## Exploring ObjSize influence on Positioning error

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
# import data
df = pd.read_csv('../data/IEEE_2024_positioning_evaluation_with_size_data.csv')

# %%
df.head()
# Out:
#              image setup  Trunk-Cam_dist[mm] ObjType  Position  ObjSizeX  \
# 0  color_1_1_0.png    2D              1549.0   Apple         1   0.06909
# 1  color_1_1_0.png    2D              1549.0   Apple         2   0.06463
# 2  color_1_1_0.png    2D              1549.0   Apple         3   0.06987
# 3  color_1_1_0.png    2D              1549.0   Apple         4   0.06508
# 4  color_1_1_0.png    2D              1549.0   Apple         5   0.06464
#
#    ObjSizeY  ObjSizeZ  Xgt[m]  Ygt[m]  Zgt[m]  Xestimated[m]  Yestimated[m]  \
# 0   0.06714   0.05979   0.465   0.072   1.860          0.465          0.060
# 1   0.06205   0.05376   0.000   0.072   1.863          0.000          0.060
# 2   0.06844   0.06317  -0.465   0.073   1.858         -0.465          0.036
# 3   0.06317   0.05831   0.467   0.072   1.561          0.467          0.050
# 4   0.06348   0.06145   0.000   0.073   1.559          0.000          0.060
#
#    Zestimated[m]  Manhattan[m]  Euclidean[m]
# 0          1.910          0.06      0.050990
# 1          1.913          0.06      0.050990
# 2          1.878          0.05      0.036056
# 3          1.601          0.06      0.044721
# 4          1.609          0.06      0.050990

# %%
# Plotting FSize[1] vs Manhattan and Euclidean distances
plt.figure(figsize=(10, 6))

# Scatter plot for Manhattan distance
plt.scatter(df['ObjSizeX'].values, df['Manhattan[m]'].values, label="Manhattan Distance", marker='o', c='k')
plt.scatter(df['ObjSizeY'].values, df['Manhattan[m]'].values, marker='o', c='k')
plt.scatter(df['ObjSizeZ'].values, df['Manhattan[m]'].values, marker='o', c='k')

# Scatter plot for Euclidean distance
plt.scatter(df['ObjSizeX'].values, df['Euclidean[m]'].values, label="Euclidean Distance", marker='s', c='gray')
plt.scatter(df['ObjSizeY'].values, df['Euclidean[m]'].values, marker='s', c='gray')
plt.scatter(df['ObjSizeZ'].values, df['Euclidean[m]'].values, marker='s', c='gray')

plt.xlabel("Object size (m)")
plt.ylabel("Positioning error (m)")
plt.title("Influence of Fruit Size on Manhattan and Euclidean Errors")
plt.legend()
plt.grid(True)
plt.savefig('../docs/images/FSize_and_positioning-error-scatterplot.png', dpi=400)
plt.show()


# Select only numerical columns
numerical_df = df.select_dtypes(include=['number'])
numerical_df = numerical_df[['Manhattan[m]', 'Euclidean[m]', 'ObjSizeX', 'ObjSizeY', 'ObjSizeZ']]


# Compute the correlation matrix using Pearson method
correlation_matrix = numerical_df.corr(method='pearson')

print(np.round(correlation_matrix, 3))


# Create DataFrame from correlation matrix
df_corr = pd.DataFrame(correlation_matrix, index=['Manhattan[m]', 'Euclidean[m]', 'ObjSizeX', 'ObjSizeY', 'ObjSizeZ'])

# Set up the matplotlib figure
plt.figure(figsize=(8, 6))

# Draw the heatmap

sns.heatmap(df_corr, annot=True, fmt=".2f", cmap="coolwarm", square=True, cbar_kws={'label': 'Correlation Coefficient'})

# Set title and labels
plt.title('Correlation Matrix for Manhattan, Euclidean Distances and Fruit Size', pad=20)
plt.xticks(rotation=45)
plt.yticks(rotation=45)

# Display the plot
plt.tight_layout()
plt.savefig('../docs/images/FSize_and_positioning-error-heatmap.png', dpi=400)
plt.show()
# Out:
#               Manhattan[m]  Euclidean[m]  ObjSizeX  ObjSizeY  ObjSizeZ
# Manhattan[m]         1.000         0.963    -0.076    -0.067    -0.161
# Euclidean[m]         0.963         1.000    -0.041    -0.035    -0.119
# ObjSizeX            -0.076        -0.041     1.000     0.963     0.849
# ObjSizeY            -0.067        -0.035     0.963     1.000     0.891
# ObjSizeZ            -0.161        -0.119     0.849     0.891     1.000

# %% [markdown]
# There is not an effect of fruit size on positioning performances
